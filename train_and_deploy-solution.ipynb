# %% [markdown]
# <h1>C4 Solution</h1>

# %% [markdown]
# <h3>Get the data and copy it to S3</h3>

# %%
# %%capture
# !wget https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip

# %%
# %%capture
# !unzip dogImages.zip

# %%
# %%capture
# !aws s3 cp dogImages s3://sagemaker-us-east-1-113018293535/ --recursive

# %% [markdown]
# <h3>Install and import</h3>

# %%
# %%capture
# !pip install smdebug torch torchvision tqdm

# %%
import sagemaker
import boto3
from sagemaker.tuner import CategoricalParameter, ContinuousParameter, HyperparameterTuner
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role
from sagemaker.debugger import Rule, DebuggerHookConfig, TensorBoardOutputConfig, CollectionConfig, ProfilerRule, rule_configs
from sagemaker.debugger import ProfilerConfig, FrameworkProfile
import os

# %% [markdown]
# <h3>Set up parameters, estimator, and tuner</h3>

# %%
hyperparameter_ranges = {
    "learning_rate": ContinuousParameter(0.001, 0.1),
    "batch_size": CategoricalParameter([32, 64, 128, 256, 512]),
}

role = sagemaker.get_execution_role()

objective_metric_name = "Test Loss"
objective_type = "Minimize"
metric_definitions = [{"Name": "Test Loss", "Regex": "Testing Loss: ([0-9\\.]+)"}]

# %%
estimator = PyTorch(
    entry_point="hpo.py",
    base_job_name='pytorch_dog_hpo',
    role=role,
    framework_version="1.4.0",
    instance_count=1,
    instance_type="ml.m5.xlarge",
    py_version='py3'
)

tuner = HyperparameterTuner(
    estimator,
    objective_metric_name,
    hyperparameter_ranges,
    metric_definitions,
    max_jobs=2,
    max_parallel_jobs=2,
    objective_type=objective_type
)

# %% [markdown]
# <h3>Fit the tuner</h3>

# %%
os.environ['SM_CHANNEL_TRAINING']='s3://sagemaker-us-east-1-113018293535/'
os.environ['SM_MODEL_DIR']='s3://sagemaker-us-east-1-113018293535/model/'
os.environ['SM_OUTPUT_DATA_DIR']='s3://sagemaker-us-east-1-113018293535/output/'
tuner.fit({"training": "s3://sagemaker-us-east-1-113018293535/"})
# Out:
# ...............................................................................................................................................................................................................................................................................................................................................................................................................................!

# %% [markdown]
# <h3>Describe the tuning results</h3>

# %%
from sagemaker.analytics import HyperparameterTuningJobAnalytics

exp = HyperparameterTuningJobAnalytics(
  hyperparameter_tuning_job_name='pytorch-training-220225-1914')

jobs = exp.dataframe()

jobs.sort_values('FinalObjectiveValue', ascending=0)
# Out:
#   batch_size  learning_rate                            TrainingJobName  \
# 0      "128"       0.015997  pytorch-training-220225-1914-002-2d955779
# 1      "128"       0.043973  pytorch-training-220225-1914-001-abe5a763
#
#   TrainingJobStatus  FinalObjectiveValue         TrainingStartTime  \
# 0         Completed                581.0 2022-02-25 19:17:11+00:00
# 1         Completed                580.0 2022-02-25 19:16:02+00:00
#
#             TrainingEndTime  TrainingElapsedTimeSeconds
# 0 2022-02-25 19:38:53+00:00                      1302.0
# 1 2022-02-25 19:44:47+00:00                      1725.0

# %% [markdown]
# ## Imp: If kernel dies, how to continue from a completed training job

# %%
#BetterTrainingJobName='pytorch-training-210623-2156-001-fdd5e081'

# %%
#my_estimator = sagemaker.estimator.Estimator.attach(BetterTrainingJobName)

# %%
#my_estimator.hyperparameters()

# %%
#best_estimator=my_estimator

# %% [markdown]
# <h3>Prepare to perform Training on Best Estimator</h3>

# %%
best_estimator=tuner.best_estimator()
# Out:
# 2022-03-03 04:32:03 Starting - Preparing the instances for training
# 2022-03-03 04:32:03 Downloading - Downloading input data
# 2022-03-03 04:32:03 Training - Training image download completed. Training in progress.
# 2022-03-03 04:32:03 Uploading - Uploading generated training model
# 2022-03-03 04:32:03 Completed - Training job completed

# %%
best_estimator.hyperparameters()
# Out:
# {'_tuning_objective_metric': '"Test Loss"',
#  'batch_size': '"32"',
#  'learning_rate': '0.03567339455131772',
#  'sagemaker_container_log_level': '20',
#  'sagemaker_estimator_class_name': '"PyTorch"',
#  'sagemaker_estimator_module': '"sagemaker.pytorch.estimator"',
#  'sagemaker_job_name': '"pytorch_dog_hpo-2022-03-03-04-01-48-223"',
#  'sagemaker_program': '"hpo.py"',
#  'sagemaker_region': '"us-east-1"',
#  'sagemaker_submit_directory': '"s3://sagemaker-us-east-1-113018293535/pytorch_dog_hpo-2022-03-03-04-01-48-223/source/sourcedir.tar.gz"'}

# %%
hyperparameters = {"batch_size": int(best_estimator.hyperparameters()['batch_size'].replace('"', '')), \
                   "learning_rate": best_estimator.hyperparameters()['learning_rate']}
hyperparameters
# Out:
# {'batch_size': 32, 'learning_rate': '0.03567339455131772'}

# %%
rules = [
    Rule.sagemaker(rule_configs.vanishing_gradient()),
    Rule.sagemaker(rule_configs.overfit()),
    Rule.sagemaker(rule_configs.overtraining()),
    Rule.sagemaker(rule_configs.poor_weight_initialization()),
    ProfilerRule.sagemaker(rule_configs.ProfilerReport()),
]

# %%
hook_config = DebuggerHookConfig(
    hook_parameters={
        "train.save_interval": "1",
        "eval.save_interval": "1"
    }
)

profiler_config = ProfilerConfig(
    system_monitor_interval_millis=500, framework_profile_params=FrameworkProfile(num_steps=1)
)

# %% [markdown]
# <h2>Creating an Estimator</h2>

# %%
# #adjust this cell to accomplish multi-instance training
# estimator = PyTorch(
#     entry_point='hpo.py',
#     base_job_name='dog-pytorch',
#     role=role,
#     instance_count=1,
#     instance_type='ml.m5.xlarge',
#     framework_version='1.4.0',
#     py_version='py3',
#     hyperparameters=hyperparameters,
#     ## Debugger and Profiler parameters
#     rules = rules,
#     debugger_hook_config=hook_config,
#     profiler_config=profiler_config,
# )

# %%
# estimator.fit({"training": "s3://sagemaker-us-east-1-113018293535/"}, wait=False)

# %% [markdown]
# <h2>Creating an Estimator - Multi-Instance Training,</h2>

# %%
###in this cell, create and fit an estimator using multi-instance training
estimator = PyTorch(
    entry_point='hpo.py',
    base_job_name='dog-pytorch',
    role=role,
    instance_count=5,
    instance_type='ml.m5.xlarge',
    framework_version='1.4.0',
    py_version='py3',
    hyperparameters=hyperparameters,
    ## Debugger and Profiler parameters
    rules = rules,
    debugger_hook_config=hook_config,
    profiler_config=profiler_config,
)

# %%
estimator.fit({"training": "s3://sagemaker-us-east-1-113018293535/"}, wait=True)
# Out:
# 2022-03-03 04:37:18 Starting - Starting the training job...
# 2022-03-03 04:37:35 Starting - Preparing the instances for trainingVanishingGradient: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# PoorWeightInitialization: InProgress
# ProfilerReport: InProgress
# .........
# 2022-03-03 04:39:21 Downloading - Downloading input data.....................
# 2022-03-03 04:42:59 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-03-03 04:42:53,534 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-03-03 04:42:53,537 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:53,548 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-03-03 04:42:53,553 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-03-03 04:42:54,002 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2022-03-03 04:42:54,002 sagemaker-containers INFO     Generating setup.cfg
# 2022-03-03 04:42:54,002 sagemaker-containers INFO     Generating MANIFEST.in
# 2022-03-03 04:42:54,003 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-03-03 04:42:53,456 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-03-03 04:42:53,460 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:53,473 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-03-03 04:42:53,477 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-03-03 04:42:53,923 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2022-03-03 04:42:53,923 sagemaker-containers INFO     Generating setup.cfg
# 2022-03-03 04:42:53,923 sagemaker-containers INFO     Generating MANIFEST.in
# 2022-03-03 04:42:53,924 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# 2022-03-03 04:42:53,590 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-03-03 04:42:53,593 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:53,605 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-03-03 04:42:53,610 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-03-03 04:42:54,042 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2022-03-03 04:42:54,042 sagemaker-containers INFO     Generating setup.cfg
# 2022-03-03 04:42:54,042 sagemaker-containers INFO     Generating MANIFEST.in
# 2022-03-03 04:42:54,042 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# Processing /tmp/tmpn99981dk/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
# Processing /tmp/tmpu0mf3gvq/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
# Processing /tmp/tmpbcmdr4jq/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=6321 sha256=d618ca9790a881bf1c079a963f97a4be6e025688f666105f58d30dfcf6bb61ec
#   Stored in directory: /tmp/pip-ephem-wheel-cache-im3dyde_/wheels/b4/8c/94/39a783dcae781462c5efa7f56c41b6865cfe6d658760871417
# Successfully built default-user-module-name
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=6321 sha256=d618ca9790a881bf1c079a963f97a4be6e025688f666105f58d30dfcf6bb61ec
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f2ii668n/wheels/46/ff/3d/0b8761f964272bac8373188466fba1ae110316276519addbe1
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=6321 sha256=f0b36f94638326ef3631d42562cea46d8d655832c651b11ca2ce6d9ecdf6703d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-loc7ooz3/wheels/8a/99/c5/ba075231998b7683c18b02601812559f8272915a514f00debc
# Successfully built default-user-module-name
# 2022-03-03 04:42:56,725 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:56,741 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:56,756 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:56,768 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-3",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5"
#     ],
#     "hyperparameters": {
#         "batch_size": 32,
#         "learning_rate": "0.03567339455131772"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "dog-pytorch-2022-03-03-04-37-16-413",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz",
#     "module_name": "hpo",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-3",
#         "current_instance_type": "ml.m5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.xlarge",
#                 "hosts": [
#                     "algo-5",
#                     "algo-1",
#                     "algo-4",
#                     "algo-3",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "hpo.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":32,"learning_rate":"0.03567339455131772"}
# SM_USER_ENTRY_POINT=hpo.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-3","current_instance_type":"ml.m5.xlarge","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"instance_groups":[{"hosts":["algo-5","algo-1","algo-4","algo-3","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-3
# SM_MODULE_NAME=hpo
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-3","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"hyperparameters":{"batch_size":32,"learning_rate":"0.03567339455131772"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"dog-pytorch-2022-03-03-04-37-16-413","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz","module_name":"hpo","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-3","current_instance_type":"ml.m5.xlarge","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"instance_groups":[{"hosts":["algo-5","algo-1","algo-4","algo-3","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"hpo.py"}
# SM_USER_ARGS=["--batch_size","32","--learning_rate","0.03567339455131772"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=32
# SM_HP_LEARNING_RATE=0.03567339455131772
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 hpo.py --batch_size 32 --learning_rate 0.03567339455131772
# Namespace(batch_size=32, data='/opt/ml/input/data/training', learning_rate=0.03567339455131772, model_dir='/opt/ml/model', output_dir='/opt/ml/output/data')
# Hyperparameters are LR: 0.03567339455131772, Batch Size: 32
# Data Paths: /opt/ml/input/data/training
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-03-03 04:42:53,170 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-03-03 04:42:53,174 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:53,192 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-03-03 04:42:53,196 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-03-03 04:42:53,589 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2022-03-03 04:42:53,589 sagemaker-containers INFO     Generating setup.cfg
# 2022-03-03 04:42:53,590 sagemaker-containers INFO     Generating MANIFEST.in
# 2022-03-03 04:42:53,590 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
# Processing /tmp/tmppn115xg2/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-03-03 04:42:54,548 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-03-03 04:42:54,551 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:54,565 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-03-03 04:42:54,572 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-03-03 04:42:55,231 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2022-03-03 04:42:55,231 sagemaker-containers INFO     Generating setup.cfg
# 2022-03-03 04:42:55,231 sagemaker-containers INFO     Generating MANIFEST.in
# 2022-03-03 04:42:55,231 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python3.6 -m pip install .
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=6321 sha256=d618ca9790a881bf1c079a963f97a4be6e025688f666105f58d30dfcf6bb61ec
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vbyil96q/wheels/7b/e0/69/b1947687962a9182084e58a5ba858351a6aba356461bba1e5f
# Successfully built default-user-module-name
# Processing /tmp/tmp7f6o9jb3/module_dir
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# 2022-03-03 04:42:56,443 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:56,458 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:56,471 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:56,485 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-5",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5"
#     ],
#     "hyperparameters": {
#         "batch_size": 32,
#         "learning_rate": "0.03567339455131772"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "dog-pytorch-2022-03-03-04-37-16-413",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz",
#     "module_name": "hpo",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-5",
#         "current_instance_type": "ml.m5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.xlarge",
#                 "hosts": [
#                     "algo-5",
#                     "algo-1",
#                     "algo-4",
#                     "algo-3",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "hpo.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":32,"learning_rate":"0.03567339455131772"}
# SM_USER_ENTRY_POINT=hpo.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-5","current_instance_type":"ml.m5.xlarge","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"instance_groups":[{"hosts":["algo-5","algo-1","algo-4","algo-3","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-5
# SM_MODULE_NAME=hpo
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-5","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"hyperparameters":{"batch_size":32,"learning_rate":"0.03567339455131772"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"dog-pytorch-2022-03-03-04-37-16-413","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz","module_name":"hpo","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-5","current_instance_type":"ml.m5.xlarge","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"instance_groups":[{"hosts":["algo-5","algo-1","algo-4","algo-3","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"hpo.py"}
# SM_USER_ARGS=["--batch_size","32","--learning_rate","0.03567339455131772"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=32
# SM_HP_LEARNING_RATE=0.03567339455131772
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 hpo.py --batch_size 32 --learning_rate 0.03567339455131772
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# 2022-03-03 04:42:56,983 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:57,003 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:57,017 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:57,030 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5"
#     ],
#     "hyperparameters": {
#         "batch_size": 32,
#         "learning_rate": "0.03567339455131772"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "dog-pytorch-2022-03-03-04-37-16-413",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz",
#     "module_name": "hpo",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "current_instance_type": "ml.m5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.xlarge",
#                 "hosts": [
#                     "algo-5",
#                     "algo-1",
#                     "algo-4",
#                     "algo-3",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "hpo.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":32,"learning_rate":"0.03567339455131772"}
# SM_USER_ENTRY_POINT=hpo.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.m5.xlarge","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"instance_groups":[{"hosts":["algo-5","algo-1","algo-4","algo-3","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=hpo
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"hyperparameters":{"batch_size":32,"learning_rate":"0.03567339455131772"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"dog-pytorch-2022-03-03-04-37-16-413","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz","module_name":"hpo","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.m5.xlarge","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"instance_groups":[{"hosts":["algo-5","algo-1","algo-4","algo-3","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"hpo.py"}
# SM_USER_ARGS=["--batch_size","32","--learning_rate","0.03567339455131772"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=32
# SM_HP_LEARNING_RATE=0.03567339455131772
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 hpo.py --batch_size 32 --learning_rate 0.03567339455131772
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# 2022-03-03 04:42:56,773 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:56,791 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:56,806 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:56,823 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-4",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5"
#     ],
#     "hyperparameters": {
#         "batch_size": 32,
#         "learning_rate": "0.03567339455131772"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "dog-pytorch-2022-03-03-04-37-16-413",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz",
#     "module_name": "hpo",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-4",
#         "current_instance_type": "ml.m5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.xlarge",
#                 "hosts": [
#                     "algo-5",
#                     "algo-1",
#                     "algo-4",
#                     "algo-3",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "hpo.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":32,"learning_rate":"0.03567339455131772"}
# SM_USER_ENTRY_POINT=hpo.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-4","current_instance_type":"ml.m5.xlarge","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"instance_groups":[{"hosts":["algo-5","algo-1","algo-4","algo-3","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-4
# SM_MODULE_NAME=hpo
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-4","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"hyperparameters":{"batch_size":32,"learning_rate":"0.03567339455131772"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"dog-pytorch-2022-03-03-04-37-16-413","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz","module_name":"hpo","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-4","current_instance_type":"ml.m5.xlarge","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"instance_groups":[{"hosts":["algo-5","algo-1","algo-4","algo-3","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"hpo.py"}
# SM_USER_ARGS=["--batch_size","32","--learning_rate","0.03567339455131772"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=32
# SM_HP_LEARNING_RATE=0.03567339455131772
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 hpo.py --batch_size 32 --learning_rate 0.03567339455131772
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=6321 sha256=043cff4371db41c077b9b287161c59c7b8f3f2d9ec122c5151c6b2705118efbd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-97z126oa/wheels/e1/40/7f/a4eaf32543e3efb5e199aa7b9cbf7a381bc0fa30e33328a1af
# Successfully built default-user-module-name
# Namespace(batch_size=32, data='/opt/ml/input/data/training', learning_rate=0.03567339455131772, model_dir='/opt/ml/model', output_dir='/opt/ml/output/data')
# Hyperparameters are LR: 0.03567339455131772, Batch Size: 32
# Data Paths: /opt/ml/input/data/training
# Namespace(batch_size=32, data='/opt/ml/input/data/training', learning_rate=0.03567339455131772, model_dir='/opt/ml/model', output_dir='/opt/ml/output/data')
# Hyperparameters are LR: 0.03567339455131772, Batch Size: 32
# Data Paths: /opt/ml/input/data/training
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# Namespace(batch_size=32, data='/opt/ml/input/data/training', learning_rate=0.03567339455131772, model_dir='/opt/ml/model', output_dir='/opt/ml/output/data')
# Hyperparameters are LR: 0.03567339455131772, Batch Size: 32
# Data Paths: /opt/ml/input/data/training
# 2022-03-03 04:42:58,673 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:58,688 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:58,705 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2022-03-03 04:42:58,721 sagemaker-containers INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5"
#     ],
#     "hyperparameters": {
#         "batch_size": 32,
#         "learning_rate": "0.03567339455131772"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "dog-pytorch-2022-03-03-04-37-16-413",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz",
#     "module_name": "hpo",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.xlarge",
#                 "hosts": [
#                     "algo-5",
#                     "algo-1",
#                     "algo-4",
#                     "algo-3",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "hpo.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":32,"learning_rate":"0.03567339455131772"}
# SM_USER_ENTRY_POINT=hpo.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.xlarge","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"instance_groups":[{"hosts":["algo-5","algo-1","algo-4","algo-3","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=hpo
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"hyperparameters":{"batch_size":32,"learning_rate":"0.03567339455131772"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"dog-pytorch-2022-03-03-04-37-16-413","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/source/sourcedir.tar.gz","module_name":"hpo","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.xlarge","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5"],"instance_groups":[{"hosts":["algo-5","algo-1","algo-4","algo-3","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"hpo.py"}
# SM_USER_ARGS=["--batch_size","32","--learning_rate","0.03567339455131772"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=32
# SM_HP_LEARNING_RATE=0.03567339455131772
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 hpo.py --batch_size 32 --learning_rate 0.03567339455131772
# Starting Model Training
# Epoch: 0
# [2022-03-03 04:42:59.685 algo-5:45 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-03-03 04:42:59.685 algo-5:45 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-03-03 04:42:59.685 algo-5:45 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2022-03-03 04:42:59.685 algo-5:45 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-03-03 04:42:59.687 algo-5:45 INFO hook.py:382] Monitoring the collections: gradients, relu_input, losses
# [2022-03-03 04:42:59.688 algo-5:45 INFO hook.py:443] Hook is writing from the hook with pid: 45
# Starting Model Training
# Epoch: 0
# Starting Model Training
# Epoch: 0
# [2022-03-03 04:43:00.247 algo-3:46 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-03-03 04:43:00.247 algo-3:46 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-03-03 04:43:00.247 algo-3:46 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2022-03-03 04:43:00.247 algo-3:46 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-03-03 04:43:00.251 algo-3:46 INFO hook.py:382] Monitoring the collections: relu_input, losses, gradients
# [2022-03-03 04:43:00.251 algo-3:46 INFO hook.py:443] Hook is writing from the hook with pid: 46
# Starting Model Training
# Epoch: 0
# [2022-03-03 04:43:00.081 algo-4:45 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-03-03 04:43:00.082 algo-4:45 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-03-03 04:43:00.082 algo-4:45 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2022-03-03 04:43:00.082 algo-4:45 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-03-03 04:43:00.085 algo-4:45 INFO hook.py:382] Monitoring the collections: relu_input, losses, gradients
# [2022-03-03 04:43:00.085 algo-4:45 INFO hook.py:443] Hook is writing from the hook with pid: 45
# Namespace(batch_size=32, data='/opt/ml/input/data/training', learning_rate=0.03567339455131772, model_dir='/opt/ml/model', output_dir='/opt/ml/output/data')
# Hyperparameters are LR: 0.03567339455131772, Batch Size: 32
# Data Paths: /opt/ml/input/data/training
# [2022-03-03 04:43:00.334 algo-2:45 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-03-03 04:43:00.334 algo-2:45 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-03-03 04:43:00.334 algo-2:45 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2022-03-03 04:43:00.334 algo-2:45 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-03-03 04:43:00.337 algo-2:45 INFO hook.py:382] Monitoring the collections: gradients, relu_input, losses
# [2022-03-03 04:43:00.338 algo-2:45 INFO hook.py:443] Hook is writing from the hook with pid: 45
# Starting Model Training
# Epoch: 0
# [2022-03-03 04:43:02.736 algo-1:46 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-03-03 04:43:02.737 algo-1:46 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-03-03 04:43:02.737 algo-1:46 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2022-03-03 04:43:02.737 algo-1:46 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-03-03 04:43:02.740 algo-1:46 INFO hook.py:382] Monitoring the collections: gradients, relu_input, losses
# [2022-03-03 04:43:02.740 algo-1:46 INFO hook.py:443] Hook is writing from the hook with pid: 46
# VanishingGradient: InProgress
# Overfit: InProgress
# Overtraining: Error
# PoorWeightInitialization: InProgress
# VanishingGradient: InProgress
# Overfit: InProgress
# Overtraining: Error
# PoorWeightInitialization: Error
# train loss: 168.0000, acc: 0.0000, best loss: 1000000.0000
# train loss: 173.0000, acc: 0.0000, best loss: 1000000.0000
# train loss: 182.0000, acc: 0.0000, best loss: 1000000.0000
# train loss: 183.0000, acc: 0.0000, best loss: 1000000.0000
# train loss: 183.0000, acc: 0.0000, best loss: 1000000.0000
# valid loss: 150.0000, acc: 0.0000, best loss: 150.0000
# Testing Model
# valid loss: 150.0000, acc: 0.0000, best loss: 150.0000
# Testing Model
# valid loss: 150.0000, acc: 0.0000, best loss: 150.0000
# Testing Model
# valid loss: 150.0000, acc: 0.0000, best loss: 150.0000
# Testing Model
# valid loss: 150.0000, acc: 0.0000, best loss: 150.0000
# Testing Model
# ---------------------------------------------------------------------------
# CredentialRetrievalError                  Traceback (most recent call last)
# <ipython-input-21-f5354a20a33e> in <module>
# ----> 1 estimator.fit({"training": "s3://sagemaker-us-east-1-113018293535/"}, wait=True)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     690         self.jobs.append(self.latest_training_job)
#     691         if wait:
# --> 692             self.latest_training_job.wait(logs=logs)
#     693
#     694     def _compilation_job_name(self):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1665         # If logs are requested, call logs_for_jobs.
#    1666         if logs != "None":
# -> 1667             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1668         else:
#    1669             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3728                 positions,
#    3729                 dot,
# -> 3730                 color_wrap,
#    3731             )
#    3732             if state == LogState.COMPLETE:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/session.py in _flush_log_streams(stream_names, instance_count, client, log_group, job_name, positions, dot, color_wrap)
#    4823             dot = False
#    4824         for idx, event in sagemaker.logs.multi_stream_iter(
# -> 4825             client, log_group, stream_names, positions
#    4826         ):
#    4827             color_wrap(idx, event["message"])
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/logs.py in multi_stream_iter(client, log_group, streams, positions)
#     120             continue
#     121         try:
# --> 122             events.append(next(s))
#     123         except StopIteration:
#     124             events.append(None)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/logs.py in log_stream(client, log_group, stream_name, start_time, skip)
#     167             startTime=start_time,
#     168             startFromHead=True,
# --> 169             **token_arg
#     170         )
#     171         next_token = response["nextForwardToken"]
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     389                     "%s() only accepts keyword arguments." % py_operation_name)
#     390             # The "self" in this scope is referring to the BaseClient.
# --> 391             return self._make_api_call(operation_name, kwargs)
#     392
#     393         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     704         else:
#     705             http, parsed_response = self._make_request(
# --> 706                 operation_model, request_dict, request_context)
#     707
#     708         self.meta.events.emit(
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     723     def _make_request(self, operation_model, request_dict, request_context):
#     724         try:
# --> 725             return self._endpoint.make_request(operation_model, request_dict)
#     726         except Exception as e:
#     727             self.meta.events.emit(
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     102         logger.debug("Making request for %s with params: %s",
#     103                      operation_model, request_dict)
# --> 104         return self._send_request(request_dict, operation_model)
#     105
#     106     def create_request(self, params, operation_model=None):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     132     def _send_request(self, request_dict, operation_model):
#     133         attempts = 1
# --> 134         request = self.create_request(request_dict, operation_model)
#     135         context = request_dict['context']
#     136         success_response, exception = self._get_response(
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/endpoint.py in create_request(self, params, operation_model)
#     116                 op_name=operation_model.name)
#     117             self._event_emitter.emit(event_name, request=request,
# --> 118                                      operation_name=operation_model.name)
#     119         prepared_request = self.prepare_request(request)
#     120         return prepared_request
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/hooks.py in emit(self, event_name, **kwargs)
#     355     def emit(self, event_name, **kwargs):
#     356         aliased_event_name = self._alias_event_name(event_name)
# --> 357         return self._emitter.emit(aliased_event_name, **kwargs)
#     358
#     359     def emit_until_response(self, event_name, **kwargs):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/hooks.py in emit(self, event_name, **kwargs)
#     226                  handlers.
#     227         """
# --> 228         return self._emit(event_name, kwargs)
#     229
#     230     def emit_until_response(self, event_name, **kwargs):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#     209         for handler in handlers_to_call:
#     210             logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 211             response = handler(**kwargs)
#     212             responses.append((handler, response))
#     213             if stop_on_response and response is not None:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/signers.py in handler(self, operation_name, request, **kwargs)
#      91         # this method is invoked to sign the request.
#      92         # Don't call this method directly.
# ---> 93         return self.sign(operation_name, request)
#      94
#      95     def sign(self, operation_name, request, region_name=None,
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/signers.py in sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     155                 kwargs['signing_name'] = signing_context['signing_name']
#     156             try:
# --> 157                 auth = self.get_auth_instance(**kwargs)
#     158             except UnknownSignatureVersionError as e:
#     159                 if signing_type != 'standard':
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/signers.py in get_auth_instance(self, signing_name, region_name, signature_version, **kwargs)
#     235         frozen_credentials = None
#     236         if self._credentials is not None:
# --> 237             frozen_credentials = self._credentials.get_frozen_credentials()
#     238         kwargs['credentials'] = frozen_credentials
#     239         if cls.REQUIRES_REGION:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/credentials.py in get_frozen_credentials(self)
#     627
#     628         """
# --> 629         self._refresh()
#     630         return self._frozen_credentials
#     631
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/credentials.py in _refresh(self)
#     522                 is_mandatory_refresh = self.refresh_needed(
#     523                     self._mandatory_refresh_timeout)
# --> 524                 self._protected_refresh(is_mandatory=is_mandatory_refresh)
#     525                 return
#     526             finally:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/credentials.py in _protected_refresh(self, is_mandatory)
#     553             # set of temporary credentials we have.
#     554             return
# --> 555         self._set_from_data(metadata)
#     556         self._frozen_credentials = ReadOnlyCredentials(
#     557             self._access_key, self._secret_key, self._token)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/credentials.py in _set_from_data(self, data)
#     582             raise CredentialRetrievalError(
#     583                 provider=self.method,
# --> 584                 error_msg=message % ', '.join(missing_keys),
#     585             )
#     586
#
# CredentialRetrievalError: Error when retrieving credentials from iam-role: Credential refresh failed, response did not contain: access_key, secret_key, token, expiry_time

# %% [markdown]
# <h2>Deployment</h2>

# %%
model_location=estimator.model_data
model_location
# Out:
# 's3://sagemaker-us-east-1-113018293535/dog-pytorch-2022-03-03-04-37-16-413/output/model.tar.gz'

# %%
import sagemaker
import boto3
from sagemaker.tuner import CategoricalParameter, ContinuousParameter, HyperparameterTuner
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role
from sagemaker.debugger import Rule, DebuggerHookConfig, TensorBoardOutputConfig, CollectionConfig, ProfilerRule, rule_configs
from sagemaker.debugger import ProfilerConfig, FrameworkProfile

from sagemaker.pytorch import PyTorchModel
from sagemaker.predictor import Predictor

# %%
jpeg_serializer = sagemaker.serializers.IdentitySerializer("image/jpeg")
json_deserializer = sagemaker.deserializers.JSONDeserializer()


class ImagePredictor(Predictor):
    def __init__(self, endpoint_name, sagemaker_session):
        super(ImagePredictor, self).__init__(
            endpoint_name,
            sagemaker_session=sagemaker_session,
            serializer=jpeg_serializer,
            deserializer=json_deserializer,
        )

# %%
pytorch_model = PyTorchModel(model_data=model_location, role=role, entry_point='infernce2.py',py_version='py3',
                             framework_version='1.4',
                             predictor_cls=ImagePredictor)

# %%
predictor = pytorch_model.deploy(initial_instance_count=1, instance_type='ml.m5.large',endpoint_name='dog-image-endpoint')
# Out:
# -----!

# %%
import requests
#request_dict={ "url": "https://cdn1-www.cattime.com/assets/uploads/2011/12/file_2744_british-shorthair-460x290-460x290.jpg" }
request_dict={ "url": "https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/20113314/Carolina-Dog-standing-outdoors.jpg" }

img_bytes = requests.get(request_dict['url']).content
type(img_bytes)

# %%
from PIL import Image
import io
Image.open(io.BytesIO(img_bytes))

# %%
response=predictor.predict(img_bytes, initial_args={"ContentType": "image/jpeg"})

# %%
import json
response2=predictor.predict(json.dumps(request_dict), initial_args={"ContentType": "application/json"})

# %%
type(response2[0][0])

# %%
response2[0]

# %%
import torch
import numpy as np
np.argmax(response, 1)

# %%
predictor
